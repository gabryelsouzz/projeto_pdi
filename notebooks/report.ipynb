# %% [markdown]
# # Report do Núcleo
#
# Este notebook documenta e demonstra, de forma prática, como as funções do diretório `core/` implementam matematicamente conteúdos fundamentais de Processamento Digital de Imagens (PDI).
#
# O foco não está apenas em mostrar resultados visuais, mas em explicar:
#
# - qual conceito teórico cada função representa;
# - qual é a formulação matemática envolvida;
# - como essa formulação aparece no código;
# - e como o resultado pode ser interpretado visualmente na ferramenta.
#
# ## Estrutura analisada
#
# Os arquivos centrais deste report são:
#
# - `core/basics.py`
# - `core/linear.py`
# - `core/equalize.py`
# - `core/match.py`
# - `core/thresholding.py`
# - `core/transforms.py`
#
# Esses módulos correspondem às principais técnicas implementadas na ferramenta interativa de manipulação de histograma.

# %%
import sys
from pathlib import Path

import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

ROOT = Path("..").resolve()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from core.basics import get_histogram, compute_pdf, compute_cdf
from core.linear import linear_transformation, autoscale
from core.equalize import equalize
from core.match import match
from core.thresholding import threshold

plt.style.use("default")

# %% [markdown]
# ## load()
# Carrega imagem ao python. Com `Image.open()` a imagem é carregada com o caminho indicadom e `.convert("L")` a converte numa imagem de 256 tons de cinza.
#
# `np.array()` converte a imagem num array de interios de 8 bits sem notação de sinal

# %% [markdown]
# ## save()
# Salva a imagem no caminho indicado

# %% [markdown]
# Sal
